# %% [markdown]
# <a href="https://colab.research.google.com/github/tasnim-fatema/AER850_project3/blob/main/AER850_project3_YOLO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step 1: Install required libraries
# !pip install ultralytics

# Step 2: Import necessary packages
from ultralytics import YOLO
from google.colab import drive
import os

drive.mount('/content/drive')
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.7/898.7 kB 54.1 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Mounted at /content/drive

# %%
# Step 4: Configure and load the YOLOv8 nano model
# Initialize the model with the YOLOv8-nano configuration
model = YOLO('yolov8n.pt')  # Ensure this model file exists or use a pre-trained version

# Step 5: Define the dataset location
DATASET_PATH = '/content/drive/MyDrive/AER850/data/data.yaml'  # Path to your dataset configuration file

# Step 6: Configure hyperparameters for training
EPOCHS = 185
BATCH_SIZE = 4
IMG_SIZE = 1200
MODEL_NAME = "pcb_detection_yolov8n"  # Name for the trained model

# %%
# Step 7: Train the model
model.train(
    data=DATASET_PATH,   # Path to the dataset configuration file
    epochs=EPOCHS,       # Number of training epochs
    batch=BATCH_SIZE,    # Batch size for training
    imgsz=IMG_SIZE,      # Input image size
    name=MODEL_NAME      # Model name for saving results
)
# Out:
# Ultralytics 8.3.49 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import shutil
import os

# Define the model name
MODEL_NAME = "pcb_detection_yolov8n"  # Name for the trained model

# Define source and destination paths
source_folder = f'/content/runs/detect/{MODEL_NAME}/'
new_destination_folder = '/content/drive/MyDrive/AER850/data/evaluation'  # Your specified destination folder

# List of files to copy
files_to_copy = ['confusion_matrix.png', 'another_file.png']  # Update this list with the specific files you need to copy

# Ensure the destination folder exists
os.makedirs(new_destination_folder, exist_ok=True)

# Copy each file to the new destination folder
for file_name in files_to_copy:
    source_file = os.path.join(source_folder, file_name)
    destination_file = os.path.join(new_destination_folder, file_name)
    if os.path.exists(source_file):
        shutil.copy(source_file, destination_file)
        print(f"Copied {source_file} to {destination_file}")
    else:
        print(f"File not found: {source_file}")
# Out:
# File not found: /content/runs/detect/pcb_detection_yolov8n/confusion_matrix.png
# File not found: /content/runs/detect/pcb_detection_yolov8n/another_file.png

# %%
import shutil
import os
import matplotlib.pyplot as plt
import cv2

# Define the model name
MODEL_NAME = "pcb_detection_yolov8n2"  # Name for the trained model

# Define source and destination paths
source_folder = f'/content/runs/detect/{MODEL_NAME}/'
new_destination_folder = '/content/drive/MyDrive/AER850/data/evaluation'  # Your specified destination folder

# Ensure the new destination folder exists
os.makedirs(new_destination_folder, exist_ok=True)

# List of files to copy and display
files_to_copy = [
    'confusion_matrix.png',
    'confusion_matrix_normalized.png',
    'P_curve.png',
    'R_curve.png',
    'PR_curve.png',
    'F1_curve.png'
]

# Copy each file to the new destination folder and display them
for file_name in files_to_copy:
    shutil.copy(os.path.join(source_folder, file_name), new_destination_folder)
    # Load and display the image
    img = cv2.imread(os.path.join(source_folder, file_name))
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.figure(figsize=(10, 8))
    plt.imshow(img_rgb)
    plt.title(file_name)
    plt.axis('off')
    plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Path to the single evaluation image
evaluation_image = '/content/drive/MyDrive/AER850/data/evaluation/arduno.jpg'
# Path to save the output image with a different name
output_image_path = '/content/drive/MyDrive/AER850/data/evaluation/epoch_185_imgsize_1200_2.jpg'

# Run prediction and save results
results = model.predict(evaluation_image, save=True)

# Display the annotated image with bounding boxes, component names, and confidence scores
img = cv2.imread(results[0].path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Define lighter colors for components that stand out against a blue background
colors = [(240, 128, 128), (176, 224, 230), (216, 191, 216), (255, 182, 193)]  # Light coral, light cyan, thistle, light pink

# Access bounding boxes, confidence scores, and class labels
for i, (*xyxy, conf, cls) in enumerate(results[0].boxes.data):
    x1, y1, x2, y2 = map(int, xyxy)  # Bounding box coordinates
    label = model.names[int(cls)]    # Class label
    color = colors[i % len(colors)]  # Cycle through colors

    # Draw bounding box and add component name and confidence score to the image
    cv2.rectangle(img, (x1, y1), (x2, y2), color, 2)
    cv2.putText(img, f'{label} {conf:.2f}', (x1, y1 - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)  # Bold text

# Save the annotated image to Google Drive with the new name
cv2.imwrite(output_image_path, cv2.cvtColor(img, cv2.COLOR_RGB2BGR))

plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# image 1/1 /content/drive/MyDrive/AER850/data/evaluation/arduno.jpg: 832x1216 15 Capacitors, 10 Connectors, 3 Diodes, 2 Electrolytic Capacitors, 6 ICs, 2 Leds, 1 Pads, 12 Resistors, 14.0ms
# Speed: 7.7ms preprocess, 14.0ms inference, 1.8ms postprocess per image at shape (1, 3, 832, 1216)
# Results saved to runs/detect/pcb_detection_yolov8n23

# %%
import cv2
import matplotlib.pyplot as plt

# Path to the single evaluation image
evaluation_image = '/content/drive/MyDrive/AER850/data/evaluation/ardmega.jpg'
# Path to save the output image with a different name
output_image_path = '/content/drive/MyDrive/AER850/data/evaluation/epoch_185_imgsize_1200_3.jpg'

# Run prediction and save results
results = model.predict(evaluation_image, save=True)

# Display the annotated image with bounding boxes, component names, and confidence scores
img = cv2.imread(results[0].path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Define lighter colors for components that stand out against a blue background
colors = [(240, 128, 128), (176, 224, 230), (216, 191, 216), (255, 182, 193)]  # Light coral, light cyan, thistle, light pink

# Access bounding boxes, confidence scores, and class labels
for i, (*xyxy, conf, cls) in enumerate(results[0].boxes.data):
    x1, y1, x2, y2 = map(int, xyxy)  # Bounding box coordinates
    label = model.names[int(cls)]    # Class label
    color = colors[i % len(colors)]  # Cycle through colors

    # Draw bounding box and add component name and confidence score to the image
    cv2.rectangle(img, (x1, y1), (x2, y2), color, 6)  # Significantly thicker bounding box
    cv2.putText(img, f'{label} {conf:.2f}', (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 1, color, 3)  # Bigger, bold text

# Save the annotated image to Google Drive with the new name
cv2.imwrite(output_image_path, cv2.cvtColor(img, cv2.COLOR_RGB2BGR))

plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# image 1/1 /content/drive/MyDrive/AER850/data/evaluation/ardmega.jpg: 1088x1216 1 Button, 13 Capacitors, 9 Connectors, 2 Diodes, 1 Electrolytic Capacitor, 7 ICs, 1 Led, 20 Resistors, 67.8ms
# Speed: 15.1ms preprocess, 67.8ms inference, 2.5ms postprocess per image at shape (1, 3, 1088, 1216)
# Results saved to runs/detect/pcb_detection_yolov8n24

# %%
import cv2
import matplotlib.pyplot as plt


# Path to the single evaluation image
evaluation_image = '/content/drive/MyDrive/AER850/data/evaluation/rasppi.jpg'
# Path to save the output image with the new name
output_image_path = '/content/drive/MyDrive/AER850/data/evaluation/epoch_185_imgsize_1200_1.jpg'

# Run prediction and save results
results = model.predict(evaluation_image, save=True)

# Display the annotated image with bounding boxes, component names, and confidence scores
img = cv2.imread(results[0].path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Define lighter colors that stand out against dark green background
colors = [(255, 182, 193), (216, 191, 216), (173, 216, 230), (240, 128, 128)]  # Light pink, light purple, light blue, light coral

# Access bounding boxes, confidence scores, and class labels
for i, (*xyxy, conf, cls) in enumerate(results[0].boxes.data):
    x1, y1, x2, y2 = map(int, xyxy)  # Bounding box coordinates
    label = model.names[int(cls)]    # Class label
    color = colors[i % len(colors)]  # Cycle through colors

    # Draw bounding box and add component name and confidence score to the image
    cv2.rectangle(img, (x1, y1), (x2, y2), color, 4)  # Increase thickness from 2 to 4
    cv2.putText(img, f'{label} {conf:.2f}', (x1, y1 - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.7, color, 2)

# Save the annotated image to Google Drive with the new name
cv2.imwrite(output_image_path, cv2.cvtColor(img, cv2.COLOR_RGB2BGR))

plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# image 1/1 /content/drive/MyDrive/AER850/data/evaluation/rasppi.jpg: 832x1216 22 Capacitors, 9 Connectors, 2 Electrolytic Capacitors, 10 ICs, 2 Leds, 1 Pads, 17 Resistors, 1 Switch, 14.7ms
# Speed: 7.7ms preprocess, 14.7ms inference, 1.5ms postprocess per image at shape (1, 3, 832, 1216)
# Results saved to runs/detect/pcb_detection_yolov8n25
